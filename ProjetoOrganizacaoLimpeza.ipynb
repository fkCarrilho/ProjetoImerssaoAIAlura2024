# %% [markdown]
# <a href="https://colab.research.google.com/github/fkCarrilho/ProjetoImerssaoAIAlura2024/blob/main/ProjetoOrganizacaoLimpeza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   Não tenho experiência nenhum com Python e nessa Imerssão ministrada por vocês tive esse primeiro contato com a ferramenta.
#
# 2.   Gostaria de mais tempo para por a mão no código e apresentar a idéia do Sistema para Organização e Limpeza (OL) tem como objetivo reunir com ajuda de voluntários para um multirão de limpeza no desastre natural do Estado do Rio Grande do Sul.

# %%
# Neste projeto para Imerssão da Alura estou importando um arquivo .csv modelo de algumas cidades afetadas pela enchente (ciente de que foram mais cidades "infelizmente").
# em seguida mostro um gráfico desse arquivo e chamo interagindo com o chat-bot.

# Percorrer a pasta com arquivo
import os
import pandas as pd

lista_arquivo = os.listdir("/content/drive/MyDrive/Python/Cidades/")
print(lista_arquivo)

tabela_populacao = pd.DataFrame()
# Ler o arquivo
for arquivo in lista_arquivo:
  # importar arquivo
    tabela = pd.read_csv(f"/content/drive/MyDrive/Python/Cidades/{arquivo}")
    display(tabela)
# Out:
# ['Afetados.csv']
#     Prosição                   Cidade  população
# 0          1                   Aceguá      4 170
# 1          2                    Agudo     16 039
# 2          3                Ajuricaba      6 720
# 3          4                  Alecrim      6 123
# 4          5                 Alegrete     72 409
# 5          6                  Alegria      3 651
# 6          7         Barra do Ribeiro     12 225
# 7          8            Barros Cassal      9 296
# 8          9          Bento Gonçalves    123 151
# 9         10         Boa Vista do Sul      2 779
# 10        11      Capão Bonito do Sul      1 733
# 11        12        Capela de Santana     11 159
# 12        13  Doutor Maurício Cardoso      4 470
# 13        14           Doutor Ricardo      1 888
# 14        15      Encruzilhada do Sul     23 819
# 15        16            Estrela Velha      3 070
# 16        17        Eugênio de Castro      2 633
# 17        18              Farroupilha     69 885
# ...

# %% [markdown]
# *   Exibir Gráfico

# %%
import plotly.express as px

#grafico = px.bar(tabela, x=tabela.index, y='população')
colunas = tabela.Cidade
grafico_pizza = px.pie(values=tabela.index, names=colunas, title='População mais atingidas pela enchente', color_discrete_sequence=px.colors.qualitative.Set3)
grafico_pizza.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *   Interação com Chat Bot
